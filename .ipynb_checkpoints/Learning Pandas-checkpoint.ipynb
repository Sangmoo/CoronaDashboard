# %%
import pandas as pd

daily_df = pd.read_csv("data/daily_report.csv")

daily_df # All Data

#daily_df["Country_Region"]

#daily_df = daily_df[["Confirmed", "Deaths", "Recovered"]].sum() # Sum Data

#daily_df = daily_df[["Confirmed", "Deaths", "Recovered"]].sum().reset_index()

daily_df = daily_df[["Confirmed", "Deaths", "Recovered"]].sum().reset_index(name="Count")
daily_df = daily_df.rename(columns={"index":"condition"})

daily_df

#print(daily_df)
#print(daily_df.head())

#type(daily_df) # Type Check
# Out:
#    condition     Count
# 0  Confirmed  22136954
# 1     Deaths    780908
# 2  Recovered  14116451

# %%
import pandas as pd

daily_df = pd.read_csv("data/daily_report.csv")
daily_df = daily_df[["Country_Region", "Confirmed", "Deaths", "Recovered"]]

daily_df = daily_df.groupby("Country_Region").sum().reset_index()
daily_df
# Out:
#          Country_Region  Confirmed  Deaths  Recovered
# 0           Afghanistan      37599    1375      27166
# 1               Albania       7654     232       3871
# 2               Algeria      39444    1391      27653
# 3               Andorra       1005      53        869
# 4                Angola       1966      90        667
# ..                  ...        ...     ...        ...
# 183  West Bank and Gaza      17306     113       9939
# 184      Western Sahara         10       1          8
# 185               Yemen       1889     537       1052
# 186              Zambia       9981     264       8776
# 187            Zimbabwe       5378     141       4105
#
# [188 rows x 4 columns]

# %%
import pandas as pd

conditions = ["confirmed", "deaths", "recovered"]

def make_global_df(condition):
    df = pd.read_csv(f"data/time_{condition}.csv")
    #df = df.sum()
    df = df.drop(["Province/State", "Country/Region", "Lat", "Long"], axis = 1).sum().reset_index(name=condition)
    df = df.rename(columns={"index":"Date"})
    return df

final_df = None

for condition in conditions:
    condition_df = make_global_df(condition)
    if final_df is None:
        final_df = condition_df
    else:
        final_df = final_df.merge(condition_df)
        
final_df
# Out:
#       Date  confirmed
# 0  1/22/20        555
# 1  1/23/20        654
# 2  1/24/20        941
# 3  1/25/20       1434
# 4  1/26/20       2118
#       Date  deaths
# 0  1/22/20      17
# 1  1/23/20      18
# 2  1/24/20      26
# 3  1/25/20      42
# 4  1/26/20      56
#       Date  recovered
# 0  1/22/20         28
# 1  1/23/20         30
# 2  1/24/20         36
# 3  1/25/20         39
# 4  1/26/20         52

# %%
import pandas as pd

conditions = ["confirmed", "deaths", "recovered"]

def make_country_df(condition, country):
    df = pd.read_csv(f"data/time_confirmed.csv")
    df = df.loc[df["Country/Region"] == country # dType : bool
    df = df.drop(columns=["Province/State", "Country/Region", "Lat", "Long"]).sum().reset_index(name=condition)
    df = df.rename(columns={'index':'Date'})
    return df

                
final_df = None

for condition in conditions:
    condition_df = make_country_df(condition, "Korea, South")
    if final_df is None:
        final_df = condition_df
    else:
        final_df = final_df.merge(condition_df)
        
final_df
# Out:
#   File "<ipython-input-31-99dc05066138>", line 8
#     df = df.drop(columns=["Province/State", "Country/Region", "Lat", "Long"]).sum().reset_index(name=condition)
#      ^
# SyntaxError: invalid syntax
