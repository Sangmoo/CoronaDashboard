# %%
import pandas as pd

daily_df = pd.read_csv("data/daily_report.csv")

daily_df

daily_df[Country_Region]
# Out:
#       FIPS Admin2 Province_State      Country_Region          Last_Update  \
# 0      NaN    NaN            NaN         Afghanistan  2020-08-19 04:27:47
# 1      NaN    NaN            NaN             Albania  2020-08-19 04:27:47
# 2      NaN    NaN            NaN             Algeria  2020-08-19 04:27:47
# 3      NaN    NaN            NaN             Andorra  2020-08-19 04:27:47
# 4      NaN    NaN            NaN              Angola  2020-08-19 04:27:47
# ...    ...    ...            ...                 ...                  ...
# 3942   NaN    NaN            NaN  West Bank and Gaza  2020-08-19 04:27:47
# 3943   NaN    NaN            NaN      Western Sahara  2020-08-19 04:27:47
# 3944   NaN    NaN            NaN               Yemen  2020-08-19 04:27:47
# 3945   NaN    NaN            NaN              Zambia  2020-08-19 04:27:47
# 3946   NaN    NaN            NaN            Zimbabwe  2020-08-19 04:27:47
#
#             Lat      Long_  Confirmed  Deaths  Recovered   Active  \
# ...
